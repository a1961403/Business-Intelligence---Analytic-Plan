# %%
import pandas as pd

# %%
# Job posting db
job_post = pd.read_csv('linkedin_job_postings.csv')

# %%
#export this to an excel file
# 2. Extract just the first 50 rows
sample_jp = job_post.head(50)

# 3. Export only the 50-row sample to Excel
sample_jp.to_excel('sample_job_postings_50.xlsx', index=False)

# %%
# Job skill db
job_skills = pd.read_csv('job_skills.csv')

# %%
#export this to an excel file 
# 2. Extract just the first 50 rows
sample_js = job_skills.head(50)

# 3. Export only the 50-row sample to Excel
sample_js.to_excel('sample_job_skills_50.xlsx', index=False)

# %%
job_skills
# Out:
#                                                   job_link  \
# 0        https://www.linkedin.com/jobs/view/housekeeper...
# 1        https://www.linkedin.com/jobs/view/assistant-g...
# 2        https://www.linkedin.com/jobs/view/school-base...
# 3        https://www.linkedin.com/jobs/view/electrical-...
# 4        https://www.linkedin.com/jobs/view/electrical-...
# ...                                                    ...
# 1296376  https://www.linkedin.com/jobs/view/community-a...
# 1296377  https://www.linkedin.com/jobs/view/sr-it-analy...
# 1296378  https://www.linkedin.com/jobs/view/operations-...
# 1296379  https://www.linkedin.com/jobs/view/float-patie...
# 1296380  https://www.linkedin.com/jobs/view/conductor-e...
#
#                                                 job_skills
# 0        Building Custodial Services, Cleaning, Janitor...
# 1        Customer service, Restaurant management, Food ...
# 2        Applied Behavior Analysis (ABA), Data analysis...
# 3        Electrical Engineering, Project Controls, Sche...
# 4        Electrical Assembly, Point to point wiring, St...
# ...                                                    ...
# 1296376  Communication Skills, Time Management, Custome...
# 1296377  Windows SQL, EDI X12, Edifecs Platform, Health...
# 1296378  Adaptability, Communication, Digital Fluency, ...
# 1296379  CNA, EMT, BLS, Medical Assistant, CPCT, LPN, R...
# 1296380  Customer Service, Driving, Loading, Unloading,...
#
# [1296381 rows x 2 columns]

# %%
job_post
# Out:
#                                                   job_link  \
# 0        https://www.linkedin.com/jobs/view/account-exe...
# 1        https://www.linkedin.com/jobs/view/registered-...
# 2        https://www.linkedin.com/jobs/view/restaurant-...
# 3        https://www.linkedin.com/jobs/view/independent...
# 4        https://www.linkedin.com/jobs/view/group-unit-...
# ...                                                    ...
# 1348449  https://www.linkedin.com/jobs/view/registered-...
# 1348450  https://www.linkedin.com/jobs/view/constructio...
# 1348451  https://www.linkedin.com/jobs/view/executive-c...
# 1348452  https://www.linkedin.com/jobs/view/rn-register...
# 1348453  https://www.linkedin.com/jobs/view/on-demand-g...
#
#                    last_processed_time got_summary got_ner is_being_worked  \
# 0         2024-01-21 07:12:29.00256+00           t       t               f
# 1         2024-01-21 07:39:58.88137+00           t       t               f
# 2        2024-01-21 07:40:00.251126+00           t       t               f
# 3        2024-01-21 07:40:00.308133+00           t       t               f
# 4        2024-01-19 09:45:09.215838+00           f       f               f
# ...                                ...         ...     ...             ...
# 1348449  2024-01-20 15:21:07.786118+00           t       t               f
# 1348450  2024-01-20 15:21:10.885264+00           t       t               f
# 1348451  2024-01-21 07:40:00.304641+00           t       t               f
# 1348452  2024-01-21 00:38:39.816821+00           t       t               f
# 1348453  2024-01-21 00:38:44.231492+00           t       t               f
#
#                                                  job_title  \
# 0        Account Executive - Dispensing (NorCal/Norther...
# 1                       Registered Nurse - RN Care Manager
# 2                     RESTAURANT SUPERVISOR - THE FORKLIFT
# 3                            Independent Real Estate Agent
# 4        Group/Unit Supervisor (Systems Support Manager...
# ...                                                    ...
# 1348449  Registered Nurse (RN) #CP-RN-7998660 - 2411627...
# 1348450                        Construction Superintendent
# 1348451                 Executive Chef, Operations Support
# 1348452  RN- Registered Nurse, Analyst - - 23934913EXPP...
# 1348453  On-Demand: Guest Advocate (Cashier), General M...
#
#                               company          job_location  first_seen  \
# 0                                  BD         San Diego, CA  2024-01-15
# 1                   Trinity Health MI     Norton Shores, MI  2024-01-14
# 2             Wasatch Adaptive Sports             Sandy, UT  2024-01-14
# 3          Howard Hanna | Rand Realty  Englewood Cliffs, NJ  2024-01-16
# 4        IRS, Office of Chief Counsel          Chamblee, GA  2024-01-17
# ...                               ...                   ...         ...
# 1348449             TravelNurseSource        Providence, RI  2024-01-14
# 1348450                         Jobot        New Iberia, LA  2024-01-15
# 1348451           NEXDINE Hospitality         Riverhead, NY  2024-01-14
# 1348452             TravelNurseSource            Aurora, CO  2024-01-16
# 1348453                        Target       Culver City, CA  2024-01-12
#
#          search_city search_country                        search_position  \
# 0           Coronado  United States                            Color Maker
# 1        Grand Haven  United States               Director Nursing Service
# 2             Tooele  United States                               Stand-In
# 3          Pinehurst  United States                      Real-Estate Clerk
# 4            Gadsden  United States   Supervisor Travel-Information Center
# ...              ...            ...                                    ...
# 1348449   Fall River  United States                       Nurse Supervisor
# 1348450    Lafayette  United States  Assistant Construction Superintendent
# 1348451     Eastport  United States                                   Chef
# 1348452     Colorado  United States                   Occupational Analyst
# 1348453       Malibu  United States                             Cashier Ii
#
#           job_level job_type
# 0        Mid senior   Onsite
# 1        Mid senior   Onsite
# 2        Mid senior   Onsite
# 3        Mid senior   Onsite
# 4        Mid senior   Onsite
# ...             ...      ...
# 1348449  Mid senior   Onsite
# 1348450  Mid senior   Onsite
# 1348451  Mid senior   Onsite
# 1348452  Mid senior   Onsite
# 1348453  Mid senior   Onsite
#
# [1348454 rows x 14 columns]

# %%
#job sums again but import 1.3mil rows (similiar to the rows of the other 2 db)
job_sum = pd.read_csv('job_summary.csv',nrows=1348454)

# %%
#export this to an excel file 
# 2. Extract just the first 50 rows
sample_jsum = job_sum.head(50)

# 3. Export only the 50-row sample to Excel
sample_jsum.to_excel('sample_job_summary_50.xlsx', index=False)

# %%
job_sum
# Out:
#                                                   job_link  \
# 0        https://www.linkedin.com/jobs/view/restaurant-...
# 1        https://www.linkedin.com/jobs/view/med-surg-re...
# 2        https://www.linkedin.com/jobs/view/registered-...
# 3        https://uk.linkedin.com/jobs/view/commercial-a...
# 4        https://www.linkedin.com/jobs/view/store-manag...
# ...                                                    ...
# 1297327  https://www.linkedin.com/jobs/view/roofing-sup...
# 1297328  https://www.linkedin.com/jobs/view/service-cen...
# 1297329  https://www.linkedin.com/jobs/view/flight-qual...
# 1297330  https://www.linkedin.com/jobs/view/global-sour...
# 1297331  https://www.linkedin.com/jobs/view/research-as...
#
#                                                job_summary
# 0        Rock N Roll Sushi is hiring a Restaurant Manag...
# 1        Schedule\n: PRN is required minimum 12 hours p...
# 2        Description\nIntroduction\nAre you looking for...
# 3        Commercial account executive\nSheffield\nFull ...
# 4        Address:\nUSA-CT-Newington-44 Fenn Road\nStore...
# ...                                                    ...
# 1297327  We are currently seeking experienced commercia...
# 1297328  Overview\nStable and growing organization\nCom...
# 1297329  Rôle et responsabilités\nJob Description:\nFli...
# 1297330  Job Description\nAre You Ready to Make It Happ...
# 1297331  Current Employees:\nIf you are a current Staff...
#
# [1297332 rows x 2 columns]

# %%
job_skills
# Out:
#                                                   job_link  \
# 0        https://www.linkedin.com/jobs/view/housekeeper...
# 1        https://www.linkedin.com/jobs/view/assistant-g...
# 2        https://www.linkedin.com/jobs/view/school-base...
# 3        https://www.linkedin.com/jobs/view/electrical-...
# 4        https://www.linkedin.com/jobs/view/electrical-...
# ...                                                    ...
# 1296376  https://www.linkedin.com/jobs/view/community-a...
# 1296377  https://www.linkedin.com/jobs/view/sr-it-analy...
# 1296378  https://www.linkedin.com/jobs/view/operations-...
# 1296379  https://www.linkedin.com/jobs/view/float-patie...
# 1296380  https://www.linkedin.com/jobs/view/conductor-e...
#
#                                                 job_skills
# 0        Building Custodial Services, Cleaning, Janitor...
# 1        Customer service, Restaurant management, Food ...
# 2        Applied Behavior Analysis (ABA), Data analysis...
# 3        Electrical Engineering, Project Controls, Sche...
# 4        Electrical Assembly, Point to point wiring, St...
# ...                                                    ...
# 1296376  Communication Skills, Time Management, Custome...
# 1296377  Windows SQL, EDI X12, Edifecs Platform, Health...
# 1296378  Adaptability, Communication, Digital Fluency, ...
# 1296379  CNA, EMT, BLS, Medical Assistant, CPCT, LPN, R...
# 1296380  Customer Service, Driving, Loading, Unloading,...
#
# [1296381 rows x 2 columns]

# %%
#Step 1: concat job skills and job postings
df = job_post.merge(job_skills, on="job_link", how="left")

# %%
df.columns.tolist()
# Out:
# ['job_link',
#  'last_processed_time',
#  'got_summary',
#  'got_ner',
#  'is_being_worked',
#  'job_title',
#  'company',
#  'job_location',
#  'first_seen',
#  'search_city',
#  'search_country',
#  'search_position',
#  'job_level',
#  'job_type',
#  'job_skills']

# %%
#keep the core columns for analysis
core_col = ['job_link','job_title','company',
 'job_location', 'job_level',
 'job_type','job_skills', 'first_seen']

df_study = df[core_col]

# %%
df_study
# Out:
#                                                   job_link  \
# 0        https://www.linkedin.com/jobs/view/account-exe...
# 1        https://www.linkedin.com/jobs/view/registered-...
# 2        https://www.linkedin.com/jobs/view/restaurant-...
# 3        https://www.linkedin.com/jobs/view/independent...
# 4        https://www.linkedin.com/jobs/view/group-unit-...
# ...                                                    ...
# 1348449  https://www.linkedin.com/jobs/view/registered-...
# 1348450  https://www.linkedin.com/jobs/view/constructio...
# 1348451  https://www.linkedin.com/jobs/view/executive-c...
# 1348452  https://www.linkedin.com/jobs/view/rn-register...
# 1348453  https://www.linkedin.com/jobs/view/on-demand-g...
#
#                                                  job_title  \
# 0        Account Executive - Dispensing (NorCal/Norther...
# 1                       Registered Nurse - RN Care Manager
# 2                     RESTAURANT SUPERVISOR - THE FORKLIFT
# 3                            Independent Real Estate Agent
# 4        Group/Unit Supervisor (Systems Support Manager...
# ...                                                    ...
# 1348449  Registered Nurse (RN) #CP-RN-7998660 - 2411627...
# 1348450                        Construction Superintendent
# 1348451                 Executive Chef, Operations Support
# 1348452  RN- Registered Nurse, Analyst - - 23934913EXPP...
# 1348453  On-Demand: Guest Advocate (Cashier), General M...
#
#                               company          job_location   job_level  \
# 0                                  BD         San Diego, CA  Mid senior
# 1                   Trinity Health MI     Norton Shores, MI  Mid senior
# 2             Wasatch Adaptive Sports             Sandy, UT  Mid senior
# 3          Howard Hanna | Rand Realty  Englewood Cliffs, NJ  Mid senior
# 4        IRS, Office of Chief Counsel          Chamblee, GA  Mid senior
# ...                               ...                   ...         ...
# 1348449             TravelNurseSource        Providence, RI  Mid senior
# 1348450                         Jobot        New Iberia, LA  Mid senior
# 1348451           NEXDINE Hospitality         Riverhead, NY  Mid senior
# 1348452             TravelNurseSource            Aurora, CO  Mid senior
# 1348453                        Target       Culver City, CA  Mid senior
#
#         job_type                                         job_skills  \
# 0         Onsite  Medical equipment sales, Key competitors, Term...
# 1         Onsite  Nursing, Bachelor of Science in Nursing, Maste...
# 2         Onsite  Restaurant Operations Management, Inventory Ma...
# 3         Onsite  Real Estate, Customer Service, Sales, Negotiat...
# 4         Onsite                                                NaN
# ...          ...                                                ...
# 1348449   Onsite  Registered Nurse, BLS certification, Nursing c...
# 1348450   Onsite  Construction management, Project planning, Est...
# 1348451   Onsite  Culinary, Chef Director, Menu writing, Cycle o...
# 1348452   Onsite  Registered Nurse, Analyst, RN Registered Nurse...
# 1348453   Onsite  Customer service, Communication, Problem solvi...
#
#          first_seen
# 0        2024-01-15
# 1        2024-01-14
# 2        2024-01-14
# 3        2024-01-16
# 4        2024-01-17
# ...             ...
# 1348449  2024-01-14
# 1348450  2024-01-15
# 1348451  2024-01-14
# 1348452  2024-01-16
# 1348453  2024-01-12
#
# [1348454 rows x 8 columns]

# %%
#Step 3: check for missing value
df_study.isna().sum()
# Out:
# job_link            0
# job_title           0
# company            11
# job_location       19
# job_level           0
# job_type            0
# job_skills      54158
# first_seen          0
# dtype: int64

# %%
job_post
# Out:
#                                                   job_link  \
# 0        https://www.linkedin.com/jobs/view/account-exe...
# 1        https://www.linkedin.com/jobs/view/registered-...
# 2        https://www.linkedin.com/jobs/view/restaurant-...
# 3        https://www.linkedin.com/jobs/view/independent...
# 4        https://www.linkedin.com/jobs/view/group-unit-...
# ...                                                    ...
# 1348449  https://www.linkedin.com/jobs/view/registered-...
# 1348450  https://www.linkedin.com/jobs/view/constructio...
# 1348451  https://www.linkedin.com/jobs/view/executive-c...
# 1348452  https://www.linkedin.com/jobs/view/rn-register...
# 1348453  https://www.linkedin.com/jobs/view/on-demand-g...
#
#                    last_processed_time got_summary got_ner is_being_worked  \
# 0         2024-01-21 07:12:29.00256+00           t       t               f
# 1         2024-01-21 07:39:58.88137+00           t       t               f
# 2        2024-01-21 07:40:00.251126+00           t       t               f
# 3        2024-01-21 07:40:00.308133+00           t       t               f
# 4        2024-01-19 09:45:09.215838+00           f       f               f
# ...                                ...         ...     ...             ...
# 1348449  2024-01-20 15:21:07.786118+00           t       t               f
# 1348450  2024-01-20 15:21:10.885264+00           t       t               f
# 1348451  2024-01-21 07:40:00.304641+00           t       t               f
# 1348452  2024-01-21 00:38:39.816821+00           t       t               f
# 1348453  2024-01-21 00:38:44.231492+00           t       t               f
#
#                                                  job_title  \
# 0        Account Executive - Dispensing (NorCal/Norther...
# 1                       Registered Nurse - RN Care Manager
# 2                     RESTAURANT SUPERVISOR - THE FORKLIFT
# 3                            Independent Real Estate Agent
# 4        Group/Unit Supervisor (Systems Support Manager...
# ...                                                    ...
# 1348449  Registered Nurse (RN) #CP-RN-7998660 - 2411627...
# 1348450                        Construction Superintendent
# 1348451                 Executive Chef, Operations Support
# 1348452  RN- Registered Nurse, Analyst - - 23934913EXPP...
# 1348453  On-Demand: Guest Advocate (Cashier), General M...
#
#                               company          job_location  first_seen  \
# 0                                  BD         San Diego, CA  2024-01-15
# 1                   Trinity Health MI     Norton Shores, MI  2024-01-14
# 2             Wasatch Adaptive Sports             Sandy, UT  2024-01-14
# 3          Howard Hanna | Rand Realty  Englewood Cliffs, NJ  2024-01-16
# 4        IRS, Office of Chief Counsel          Chamblee, GA  2024-01-17
# ...                               ...                   ...         ...
# 1348449             TravelNurseSource        Providence, RI  2024-01-14
# 1348450                         Jobot        New Iberia, LA  2024-01-15
# 1348451           NEXDINE Hospitality         Riverhead, NY  2024-01-14
# 1348452             TravelNurseSource            Aurora, CO  2024-01-16
# 1348453                        Target       Culver City, CA  2024-01-12
#
#          search_city search_country                        search_position  \
# 0           Coronado  United States                            Color Maker
# 1        Grand Haven  United States               Director Nursing Service
# 2             Tooele  United States                               Stand-In
# 3          Pinehurst  United States                      Real-Estate Clerk
# 4            Gadsden  United States   Supervisor Travel-Information Center
# ...              ...            ...                                    ...
# 1348449   Fall River  United States                       Nurse Supervisor
# 1348450    Lafayette  United States  Assistant Construction Superintendent
# 1348451     Eastport  United States                                   Chef
# 1348452     Colorado  United States                   Occupational Analyst
# 1348453       Malibu  United States                             Cashier Ii
#
#           job_level job_type
# 0        Mid senior   Onsite
# 1        Mid senior   Onsite
# 2        Mid senior   Onsite
# 3        Mid senior   Onsite
# 4        Mid senior   Onsite
# ...             ...      ...
# 1348449  Mid senior   Onsite
# 1348450  Mid senior   Onsite
# 1348451  Mid senior   Onsite
# 1348452  Mid senior   Onsite
# 1348453  Mid senior   Onsite
#
# [1348454 rows x 14 columns]

# %%
df_study["job_link"].duplicated().sum()
# Out:
# np.int64(0)

# %%
#convert value in job_title column to start filter out all cell contain "business analyst"
df_study["job_title"] = (df_study["job_title"].str.lower().str.strip())

# %%
df_study
# Out:
#                                                   job_link  \
# 0        https://www.linkedin.com/jobs/view/account-exe...
# 1        https://www.linkedin.com/jobs/view/registered-...
# 2        https://www.linkedin.com/jobs/view/restaurant-...
# 3        https://www.linkedin.com/jobs/view/independent...
# 4        https://www.linkedin.com/jobs/view/group-unit-...
# ...                                                    ...
# 1348449  https://www.linkedin.com/jobs/view/registered-...
# 1348450  https://www.linkedin.com/jobs/view/constructio...
# 1348451  https://www.linkedin.com/jobs/view/executive-c...
# 1348452  https://www.linkedin.com/jobs/view/rn-register...
# 1348453  https://www.linkedin.com/jobs/view/on-demand-g...
#
#                                                  job_title  \
# 0        account executive - dispensing (norcal/norther...
# 1                       registered nurse - rn care manager
# 2                     restaurant supervisor - the forklift
# 3                            independent real estate agent
# 4        group/unit supervisor (systems support manager...
# ...                                                    ...
# 1348449  registered nurse (rn) #cp-rn-7998660 - 2411627...
# 1348450                        construction superintendent
# 1348451                 executive chef, operations support
# 1348452  rn- registered nurse, analyst - - 23934913expp...
# 1348453  on-demand: guest advocate (cashier), general m...
#
#                               company          job_location   job_level  \
# 0                                  BD         San Diego, CA  Mid senior
# 1                   Trinity Health MI     Norton Shores, MI  Mid senior
# 2             Wasatch Adaptive Sports             Sandy, UT  Mid senior
# 3          Howard Hanna | Rand Realty  Englewood Cliffs, NJ  Mid senior
# 4        IRS, Office of Chief Counsel          Chamblee, GA  Mid senior
# ...                               ...                   ...         ...
# 1348449             TravelNurseSource        Providence, RI  Mid senior
# 1348450                         Jobot        New Iberia, LA  Mid senior
# 1348451           NEXDINE Hospitality         Riverhead, NY  Mid senior
# 1348452             TravelNurseSource            Aurora, CO  Mid senior
# 1348453                        Target       Culver City, CA  Mid senior
#
#         job_type                                         job_skills  \
# 0         Onsite  Medical equipment sales, Key competitors, Term...
# 1         Onsite  Nursing, Bachelor of Science in Nursing, Maste...
# 2         Onsite  Restaurant Operations Management, Inventory Ma...
# 3         Onsite  Real Estate, Customer Service, Sales, Negotiat...
# 4         Onsite                                                NaN
# ...          ...                                                ...
# 1348449   Onsite  Registered Nurse, BLS certification, Nursing c...
# 1348450   Onsite  Construction management, Project planning, Est...
# 1348451   Onsite  Culinary, Chef Director, Menu writing, Cycle o...
# 1348452   Onsite  Registered Nurse, Analyst, RN Registered Nurse...
# 1348453   Onsite  Customer service, Communication, Problem solvi...
#
#          first_seen
# 0        2024-01-15
# 1        2024-01-14
# 2        2024-01-14
# 3        2024-01-16
# 4        2024-01-17
# ...             ...
# 1348449  2024-01-14
# 1348450  2024-01-15
# 1348451  2024-01-14
# 1348452  2024-01-16
# 1348453  2024-01-12
#
# [1348454 rows x 8 columns]

# %%
df_study[df_study["job_title"].str.contains("business analyst", na=False)]["job_title"].value_counts()
# Out:
# job_title
# business analyst                                                                                                1024
# senior business analyst                                                                                          214
# jde business analyst (supply chain)                                                                              163
# jd edwards business analyst                                                                                      150
# it business analyst                                                                                               67
#                                                                                                                 ...
# business analyst - nav/business central - sacramento - $120k                                                       1
# business analyst/scrum master - need local candidates                                                              1
# business analyst, sr.                                                                                              1
# payments business analyst                                                                                          1
# senior business analyst, salesforce, chief operating officer/strategic operations and performance management       1
# Name: count, Length: 2007, dtype: int64

# %%
df_study[df_study["job_title"].str.contains("business analyst", na=False)]["job_title"]
# Out:
# 343                          secret cleared business analyst
# 401                               business analyst (11076-1)
# 530                       payment (swift) (business analyst)
# 797                               principal business analyst
# 1258                                        business analyst
#                                  ...
# 1346654                            payments business analyst
# 1346865                             pgd sr. business analyst
# 1346983                                 business analyst - b
# 1347733    senior business analyst, salesforce, chief ope...
# 1347772                  jde business analyst (supply chain)
# Name: job_title, Length: 4576, dtype: str

# %%
df_study[df_study["job_title"].str.contains("business analyst", na=False)]["job_title"].nunique()
# Out:
# 2007

# %%
df_study[df_study["job_title"].str.contains("business analysis", na=False)]["job_title"].value_counts()
# Out:
# job_title
# business analysis and integration analyst                    5
# technical consultant - business analysis                     4
# manager, business analysis, spectrum enterprise              3
# business analysis                                            2
# senior analyst it business analysis-hybrid                   2
#                                                             ..
# business analysis manager - vice president                   1
# business analysis manager - vp - public sector operations    1
# business analysis, senior analyst (installation support)     1
# business analysis/ ms dynamics d365                          1
# manager business analysis                                    1
# Name: count, Length: 70, dtype: int64

# %%
df_study[df_study["job_title"].str.contains("business analysis", na=False)]["job_title"].nunique()
# Out:
# 70

# %%
#filter out the records contain "business analyst"
ba_df = df_study[df_study["job_title"].str.contains("business analyst", na=False)]

# %%
ba_df.isna().sum()
# Out:
# job_link          0
# job_title         0
# company           0
# job_location      0
# job_level         0
# job_type          0
# job_skills      136
# first_seen        0
# dtype: int64

# %%
#see how many records are there
len(ba_df)
# Out:
# 4576

# %%
ba_df["job_level"].value_counts()
# Out:
# job_level
# Mid senior    4057
# Associate      519
# Name: count, dtype: int64

# %%
ba_df["job_location"].value_counts()
# Out:
# job_location
# New York, NY                       105
# Boston, MA                          86
# Atlanta, GA                         85
# Chicago, IL                         68
# London, England, United Kingdom     67
#                                   ...
# Wildwood, MO                         1
# Evanston, IL                         1
# Costa Mesa, CA                       1
# Lucknow, Victoria, Australia         1
# Clifton Forge, VA                    1
# Name: count, Length: 1095, dtype: int64

# %%
location_parts = ba_df["job_location"].str.split(",").str.len()

location_parts.value_counts().sort_index()
# Out:
# job_location
# 1      75
# 2    3703
# 3     798
# Name: count, dtype: int64

# %%
ba_df[location_parts == 1]["job_location"].value_counts()
# Out:
# job_location
# United States                           15
# New York City Metropolitan Area          8
# Oklahoma City Metropolitan Area          5
# Utica-Rome Area                          5
# Greater Sydney Area                      4
# Los Angeles Metropolitan Area            3
# Greater Phoenix Area                     2
# Greater Cleveland                        2
# Greater Syracuse-Auburn Area             2
# Greater Reno Area                        2
# Greater Minneapolis-St. Paul Area        2
# Washington DC-Baltimore Area             1
# Greater Orlando                          1
# Buffalo-Niagara Falls Area               1
# Greater Philadelphia                     1
# Mexico City Metropolitan Area            1
# Greater Macon                            1
# Tallahassee Metropolitan Area            1
# Greater Anchorage Area                   1
# Greater Melbourne Area                   1
# Kansas City Metropolitan Area            1
# Nashville Metropolitan Area              1
# Cincinnati Metropolitan Area             1
# Worcester and Kidderminster Area         1
# Charlotte Metro                          1
# San Francisco Bay Area                   1
# Greater Tampa Bay Area                   1
# Greater Ottawa Metropolitan Area         1
# Miami-Fort Lauderdale Area               1
# Dallas-Fort Worth Metroplex              1
# Greater St. John's Metropolitan Area     1
# Brownsville Metropolitan Area            1
# Greater Brisbane Area                    1
# Atlanta Metropolitan Area                1
# Greater Boston                           1
# Canada                                   1
# Name: count, dtype: int64

# %%
ba_df[location_parts == 2]["job_location"].value_counts()
# Out:
# job_location
# New York, NY         105
# Boston, MA            86
# Atlanta, GA           85
# Chicago, IL           68
# Dallas, TX            58
#                     ...
# Bismarck, ND           1
# Wildwood, MO           1
# Evanston, IL           1
# Costa Mesa, CA         1
# Clifton Forge, VA      1
# Name: count, Length: 845, dtype: int64

# %%
ba_df[location_parts == 3]["job_location"].value_counts()
# Out:
# job_location
# London, England, United Kingdom             67
# Sydney, New South Wales, Australia          49
# Toronto, Ontario, Canada                    47
# Montreal, Quebec, Canada                    45
# Melbourne, Victoria, Australia              42
#                                             ..
# North Sydney, New South Wales, Australia     1
# Rockingham, Western Australia, Australia     1
# Mexicali, Baja California, Mexico            1
# Leicestershire, England, United Kingdom      1
# Lucknow, Victoria, Australia                 1
# Name: count, Length: 214, dtype: int64

# %%
ba_df["job_type"].value_counts()
# Out:
# job_type
# Onsite    4574
# Remote       1
# Hybrid       1
# Name: count, dtype: int64

# %%
df_study["job_type"].value_counts()
# Out:
# job_type
# Onsite    1337633
# Hybrid       6562
# Remote       4259
# Name: count, dtype: int64

# %%
ba_df["company"].value_counts().head(20)
# Out:
# company
# LATICRETE International                              312
# Dice                                                 168
# Tata Consultancy Services                             71
# Stellent IT                                           59
# NR Consulting                                         58
# Jobs for Humanity                                     44
# Robert Half                                           41
# Software Technology Inc.                              40
# Diverse Lynx                                          38
# Steneral Consulting                                   29
# CERES Group                                           28
# TekIntegral                                           28
# HireTalent - Diversity Staffing & Recruiting Firm     26
# Intellectt Inc                                        26
# Capital One                                           25
# ClearanceJobs                                         24
# EY                                                    22
# Capleo Global                                         22
# Extend Information Systems Inc.                       22
# Agoda                                                 22
# Name: count, dtype: int64

# %%
ba_df["job_skills"].dropna()
# Out:
# 343        Microsoft Office 365, Microsoft Teams, SharePo...
# 401        Technical Writing, Information Security, Micro...
# 797        NEER, FPL, Reliability reporting, GADS applica...
# 1271       Business Analysis, Business Requirements Gathe...
# 1525       Pricing Transparency Analyst, Data analysis, Q...
#                                  ...
# 1346654    Payments messages (Fedwire Swift), Canonical d...
# 1346865    Microsoft Excel, Powerpoint, SAP, Power BI, Bu...
# 1346983    Business Analyst, Business Systems Analysis, S...
# 1347733    Salesforce, Data Analysis, Data Interpretation...
# 1347772    JDE E1, ERP Implementation, Manufacturing, Sup...
# Name: job_skills, Length: 4440, dtype: str

# %%
skill_count = ba_df["job_skills"].str.split(",")

skill_count
# Out:
# 343        [Microsoft Office 365,  Microsoft Teams,  Shar...
# 401        [Technical Writing,  Information Security,  Mi...
# 530                                                      NaN
# 797        [NEER,  FPL,  Reliability reporting,  GADS app...
# 1258                                                     NaN
#                                  ...
# 1346654    [Payments messages (Fedwire Swift),  Canonical...
# 1346865    [Microsoft Excel,  Powerpoint,  SAP,  Power BI...
# 1346983    [Business Analyst,  Business Systems Analysis,...
# 1347733    [Salesforce,  Data Analysis,  Data Interpretat...
# 1347772    [JDE E1,  ERP Implementation,  Manufacturing, ...
# Name: job_skills, Length: 4576, dtype: object

# %%
#view how it look
skill_count.iloc[1]
# Out:
# ['Technical Writing',
#  ' Information Security',
#  ' Microsoft Office Suite',
#  ' Project Management',
#  ' POAM Processes',
#  ' CMS Regulation Compliance',
#  ' Business Analysis',
#  ' Communication Skills',
#  ' Information Technology',
#  ' Visual Aids',
#  ' Presentations',
#  ' Teamwork',
#  ' Multitasking',
#  ' Prioritization',
#  ' Attention to Detail',
#  ' Complex Processes',
#  ' Strong English Language Skills',
#  ' Grammar',
#  ' Constructive Criticism',
#  ' System Security Plans',
#  ' Advance Planning Documents',
#  ' Request For Proposals',
#  ' CMS MARSE 2.2',
#  ' NIST Risk Management Framework (RMF)',
#  ' Bizagi',
#  ' Public Sector Work Experience',
#  ' eGRC Tool',
#  " Bachelor's Degree in English Journalism or Technical Writing"]

# %%
skill_df = (
    ba_df[["job_title", "job_skills"]]
    .dropna(subset=["job_skills"])
    .copy()
)

skill_df["job_skills"] = skill_df["job_skills"].str.split(",")

skill_df = skill_df.explode("job_skills")

skill_df["job_skills"] = skill_df["job_skills"].str.strip().str.lower()

# %%
skill_df
# Out:
#                                    job_title            job_skills
# 343          secret cleared business analyst  microsoft office 365
# 343          secret cleared business analyst       microsoft teams
# 343          secret cleared business analyst     sharepoint online
# 343          secret cleared business analyst  sharepoint 2016/2019
# 343          secret cleared business analyst  microsoft powerpoint
# ...                                      ...                   ...
# 1347772  jde business analyst (supply chain)      flexible mindset
# 1347772  jde business analyst (supply chain)          adaptability
# 1347772  jde business analyst (supply chain)    hybrid/remote work
# 1347772  jde business analyst (supply chain)        extended hours
# 1347772  jde business analyst (supply chain)      us est time zone
#
# [111053 rows x 2 columns]

# %%
skill_df["job_skills"].value_counts().head(20)
# Out:
# job_skills
# business analysis         1956
# project management        1544
# data analysis             1473
# communication             1369
# sql                       1055
# analytical skills          906
# requirements gathering     779
# problem solving            774
# communication skills       742
# teamwork                   666
# agile                      659
# business analyst           547
# problemsolving             475
# stakeholder management     473
# documentation              471
# collaboration              471
# jira                       449
# excel                      446
# attention to detail        413
# bachelor's degree          412
# Name: count, dtype: int64
